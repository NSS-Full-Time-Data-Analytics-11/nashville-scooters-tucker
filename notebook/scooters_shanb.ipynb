# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sqlalchemy import create_engine, text

# %%
database_name = 'scooters'    # Fill this in with your lahman database name

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT *
FROM scooters
LIMIT 100;
'''

with engine.connect() as connection: result = connection.execute(text(query))

# %%
with engine.connect() as connection:    
    scooters = pd.read_sql(text(query), con = connection)

# %%
scooters
# Out:
#                pubdatetime   latitude  longitude  \
# 0  2019-05-25 11:34:13.000  36.120400 -86.753200
# 1  2019-05-25 11:34:13.000  36.176500 -86.785200
# 2  2019-05-25 11:34:13.000  36.120000 -86.753600
# 3  2019-05-25 11:34:13.000  36.119900 -86.753400
# 4  2019-05-25 11:34:13.000  36.120100 -86.753100
# ..                     ...        ...        ...
# 95 2019-05-25 11:34:26.863  36.153715 -86.794810
# 96 2019-05-25 11:34:26.863  36.151910 -86.781041
# 97 2019-05-25 11:34:26.863  36.161368 -86.780791
# 98 2019-05-25 11:34:26.863  36.160881 -86.776877
# 99 2019-05-25 11:34:26.863  36.159237 -86.775453
#
#                                          sumdid sumdtype  chargelevel  \
# 0   Powered9591dbfe-a6d2-5896-9d52-ef3eb92fb851  Powered         85.0
# 1   Powered7cf347a9-35e1-5551-a490-a04e98341bdb  Powered         52.0
# 2   Powered24c4e34b-b792-52c6-b90d-0450f3a71953  Powered          0.0
# 3   Poweredac715caa-251a-5cf8-a464-6e2c8d3f5048  Powered         83.0
# 4   Poweredec4aadd7-47b3-502d-a621-d3df7e1a2f63  Powered         87.0
# ..                                          ...      ...          ...
# 95                                 PoweredVZU3B  Powered        100.0
# 96                                 PoweredFB2IB  Powered        100.0
# 97                                 PoweredTD5PR  Powered         64.0
# 98                                 PoweredA34AY  Powered         66.0
# 99                                 PoweredJLFR4  Powered         52.0
#
#    sumdgroup  costpermin companyname
# 0    scooter        0.06        Jump
# 1    scooter        0.06        Jump
# 2    scooter        0.06        Jump
# 3    scooter        0.06        Jump
# 4    scooter        0.06        Jump
# ..       ...         ...         ...
# 95   scooter        0.15        Bird
# 96   scooter        0.15        Bird
# 97   scooter        0.15        Bird
# 98   scooter        0.15        Bird
# 99   scooter        0.15        Bird
#
# [100 rows x 9 columns]

# %%
scooters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pubdatetime  100 non-null    datetime64[ns]
#  1   latitude     100 non-null    float64
#  2   longitude    100 non-null    float64
#  3   sumdid       100 non-null    object
#  4   sumdtype     100 non-null    object
#  5   chargelevel  100 non-null    float64
#  6   sumdgroup    100 non-null    object
#  7   costpermin   100 non-null    float64
#  8   companyname  100 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 7.2+ KB

# %%
type(scooters)
# Out:
# pandas.core.frame.DataFrame

# %%
query = '''
SELECT *
FROM trips
LIMIT 100;
'''

with engine.connect() as connection: result = connection.execute(text(query))

# %%
with engine.connect() as connection:    
    trips = pd.read_sql(text(query), con = connection)

# %%
query = '''
SELECT Max(latitude)
FROM scooters;
'''

with engine.connect() as connection: result = connection.execute(text(query))

# %%
with engine.connect() as connection:    
    scooters = pd.read_sql(text(query), con = connection)

# %%
scooters
# Out:
#             max
# 0  3.609874e+06

# %%
query = '''
SELECT MIN(latitude)
FROM scooters;
'''

with engine.connect() as connection: result = connection.execute(text(query))

# %%
with engine.connect() as connection:    
    scooters = pd.read_sql(text(query), con = connection)   
scooters
# Out:
#    min
# 0  0.0

# %%
scooters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   min     1 non-null      float64
# dtypes: float64(1)
# memory usage: 136.0 bytes

# %%
query = '''
SELECT *
FROM scooters;
'''

with engine.connect() as connection: result = connection.execute(text(query))

# %%
with engine.connect() as connection:    
    scooters = pd.read_sql(text(query), con = connection)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[37], line 2
#       1 with engine.connect() as connection:
# ----> 2     scooters = pd.read_sql(text(query), con = connection)
#
# File ~\anaconda3\envs\scooters\lib\site-packages\pandas\io\sql.py:682, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     672     return pandas_sql.read_table(
#     673         sql,
#     674         index_col=index_col,
#    (...)
#     679         dtype_backend=dtype_backend,
#     680     )
#     681 else:
# --> 682     return pandas_sql.read_query(
#     683         sql,
#     684         index_col=index_col,
#     685         params=params,
#     686         coerce_float=coerce_float,
#     687         parse_dates=parse_dates,
#     688         chunksize=chunksize,
#     689         dtype_backend=dtype_backend,
#     690         dtype=dtype,
#     691     )
#
# File ~\anaconda3\envs\scooters\lib\site-packages\pandas\io\sql.py:1776, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1719 def read_query(
#    1720     self,
#    1721     sql: str,
#    (...)
#    1728     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1729 ) -> DataFrame | Iterator[DataFrame]:
#    1730     """
#    1731     Read SQL query into a DataFrame.
#    1732
#    (...)
#    1774
#    1775     """
# -> 1776     result = self.execute(sql, params)
#    1777     columns = result.keys()
#    1779     if chunksize is not None:
#
# File ~\anaconda3\envs\scooters\lib\site-packages\pandas\io\sql.py:1600, in SQLDatabase.execute(self, sql, params)
#    1598 if isinstance(sql, str):
#    1599     return self.con.exec_driver_sql(sql, *args)
# -> 1600 return self.con.execute(sql, *args)
#
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\engine\base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\sql\elements.py:332, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     328 def _execute_on_connection(
#     329     self, connection, multiparams, params, execution_options, _force=False
#     330 ):
#     331     if _force or self.supports_execution:
# --> 332         return connection._execute_clauseelement(
#     333             self, multiparams, params, execution_options
#     334         )
#     335     else:
#     336         raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\engine\base.py:1498, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486 compiled_cache = execution_options.get(
#    1487     "compiled_cache", self.engine._compiled_cache
#    1488 )
#    1490 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1491     dialect=dialect,
#    1492     compiled_cache=compiled_cache,
#    (...)
#    1496     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497 )
# -> 1498 ret = self._execute_context(
#    1499     dialect,
#    1500     dialect.execution_ctx_cls._init_compiled,
#    1501     compiled_sql,
#    1502     distilled_params,
#    1503     execution_options,
#    1504     compiled_sql,
#    1505     distilled_params,
#    1506     elem,
#    1507     extracted_params,
#    1508     cache_hit=cache_hit,
#    1509 )
#    1510 if has_events:
#    1511     self.dispatch.after_execute(
#    1512         self,
#    1513         elem,
#    (...)
#    1517         ret,
#    1518     )
#
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~\anaconda3\envs\scooters\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: (psycopg2.OperationalError) server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
# [SQL:
# SELECT *
# FROM scooters;
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
scooters.describe()

# %%
scooters
# Out:
#                pubdatetime   latitude  longitude  \
# 0  2019-05-25 11:34:13.000  36.120400 -86.753200
# 1  2019-05-25 11:34:13.000  36.176500 -86.785200
# 2  2019-05-25 11:34:13.000  36.120000 -86.753600
# 3  2019-05-25 11:34:13.000  36.119900 -86.753400
# 4  2019-05-25 11:34:13.000  36.120100 -86.753100
# ..                     ...        ...        ...
# 95 2019-05-25 11:34:26.863  36.153715 -86.794810
# 96 2019-05-25 11:34:26.863  36.151910 -86.781041
# 97 2019-05-25 11:34:26.863  36.161368 -86.780791
# 98 2019-05-25 11:34:26.863  36.160881 -86.776877
# 99 2019-05-25 11:34:26.863  36.159237 -86.775453
#
#                                          sumdid sumdtype  chargelevel  \
# 0   Powered9591dbfe-a6d2-5896-9d52-ef3eb92fb851  Powered         85.0
# 1   Powered7cf347a9-35e1-5551-a490-a04e98341bdb  Powered         52.0
# 2   Powered24c4e34b-b792-52c6-b90d-0450f3a71953  Powered          0.0
# 3   Poweredac715caa-251a-5cf8-a464-6e2c8d3f5048  Powered         83.0
# 4   Poweredec4aadd7-47b3-502d-a621-d3df7e1a2f63  Powered         87.0
# ..                                          ...      ...          ...
# 95                                 PoweredVZU3B  Powered        100.0
# 96                                 PoweredFB2IB  Powered        100.0
# 97                                 PoweredTD5PR  Powered         64.0
# 98                                 PoweredA34AY  Powered         66.0
# 99                                 PoweredJLFR4  Powered         52.0
#
#    sumdgroup  costpermin companyname
# 0    scooter        0.06        Jump
# 1    scooter        0.06        Jump
# 2    scooter        0.06        Jump
# 3    scooter        0.06        Jump
# 4    scooter        0.06        Jump
# ..       ...         ...         ...
# 95   scooter        0.15        Bird
# 96   scooter        0.15        Bird
# 97   scooter        0.15        Bird
# 98   scooter        0.15        Bird
# 99   scooter        0.15        Bird
#
# [100 rows x 9 columns]

# %%
scooters.describe()
# Out:
#                          pubdatetime    latitude   longitude  chargelevel  \
# count                            100  100.000000  100.000000   100.000000
# mean   2019-05-25 11:34:16.013700096   36.142339  -86.772194    50.920000
# min              2019-05-25 11:34:13   36.101400  -86.816000     0.000000
# 25%              2019-05-25 11:34:13   36.120000  -86.785125    10.750000
# 50%              2019-05-25 11:34:13   36.146850  -86.773350    53.500000
# 75%              2019-05-25 11:34:13   36.160072  -86.753400    85.000000
# max       2019-05-25 11:34:26.863000   36.182900  -86.750259   100.000000
# std                              NaN    0.021247    0.019184    36.438042
#
#        costpermin
# count   100.00000
# mean      0.07980
# min       0.06000
# 25%       0.06000
# 50%       0.06000
# 75%       0.06000
# max       0.15000
# std       0.03747

# %%
trips.head()
# Out:
#              pubtimestamp companyname triprecordnum         sumdid  \
# 0 2019-05-01 00:00:55.423        Bird       BRD2134   Powered9EAJL
# 1 2019-05-01 00:03:33.147        Lyft          LFT5  Powered296631
# 2 2019-05-01 00:05:55.570        Bird       BRD2168   Powered7S2UU
# 3 2019-05-01 00:05:55.570        Bird       BRD2166   PoweredZIIVX
# 4 2019-05-01 00:05:55.570        Bird       BRD2165   PoweredJ7MB3
#
#    tripduration  tripdistance   startdate        starttime     enddate  \
# 0        3.0000     958.00528  2019-05-01  00:00:20.460000  2019-05-01
# 1        1.7156    1371.39112  2019-05-01  00:01:50.090000  2019-05-01
# 2        3.0000    2296.58800  2019-05-01  00:03:47.363333  2019-05-01
# 3        3.0000    1200.78744  2019-05-01  00:04:21.386666  2019-05-01
# 4        2.0000     351.04988  2019-05-01  00:04:27.796666  2019-05-01
#
#            endtime  startlatitude  startlongitude  endlatitude  endlongitude  \
# 0  00:02:52.346666       36.15710       -86.80360     36.15660     -86.80670
# 1  00:03:33.026666       36.15797       -86.77896     36.16054     -86.77689
# 2  00:07:13.596666       36.15470       -86.78180     36.15650     -86.78680
# 3  00:06:59.176666       36.14940       -86.77950     36.15310     -86.77960
# 4  00:06:23.150000       36.17780       -86.78660     36.17740     -86.78760
#
#                                            triproute               create_dt
# 0  [(36.157235, -86.803612), (36.157235, -86.8036... 2019-05-02 05:30:23.780
# 1  [(36.15797, -86.77896), (36.15795, -86.77873),... 2019-05-02 07:20:32.757
# 2  [(36.155068, -86.782124), (36.156597, -86.78675)] 2019-05-02 05:30:24.530
# 3  [(36.149741, -86.779344), (36.149741, -86.7793... 2019-05-02 05:30:24.237
# 4  [(36.177699, -86.786477), (36.177711, -86.7864... 2019-05-02 05:30:24.207

# %%
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pubtimestamp    100 non-null    datetime64[ns]
#  1   companyname     100 non-null    object
#  2   triprecordnum   100 non-null    object
#  3   sumdid          100 non-null    object
#  4   tripduration    100 non-null    float64
#  5   tripdistance    100 non-null    float64
#  6   startdate       100 non-null    object
#  7   starttime       100 non-null    object
#  8   enddate         100 non-null    object
#  9   endtime         100 non-null    object
#  10  startlatitude   100 non-null    float64
#  11  startlongitude  100 non-null    float64
#  12  endlatitude     100 non-null    float64
#  13  endlongitude    100 non-null    float64
#  14  triproute       100 non-null    object
#  15  create_dt       100 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), object(8)
# memory usage: 12.6+ KB
